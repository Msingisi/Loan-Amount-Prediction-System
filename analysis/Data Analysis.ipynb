# %% [markdown]
# ### Import Analyze Source

# %%
import pandas as pd
import numpy as np

from analyze.basic_data_inspection import DataInspector, DataTypesInspectionStrategy, SummaryStatisticsInspectionStrategy
from analyze.missing_values_analysis import SimpleMissingValuesAnalysis
from analyze.univariate_analysis import UnivariateAnalyzer, NumericalUnivariateAnalysis, CategoricalUnivariateAnalysis
from analyze.bivariate_analysis import BivariateAnalyzer, NumericalVsNumericalAnalysis, CategoricalVsNumericalAnalysis
from analyze.multivariate_analysis import SimpleMultivariateAnalysis

# Set display options for better readability
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load the data

# %%
data_path = '../data/train/train.csv'
df = pd.read_csv(data_path)
df.replace(-999, 0, inplace=True)

# %%
df['Profession'].value_counts()
# Out:
# Profession
# Working                 16926
# Commercial associate     7962
# Pensioner                2740
# State servant            2366
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: count, dtype: int64

# %% [markdown]
# # Explore the data

# %% [markdown]
# ## Basic Data Inspection

# %%
data_inspector = DataInspector(DataTypesInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Data Types and Non-null Counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
# ...

# %% [markdown]
# ## Summary Statistics Inspection

# %%
data_inspector.set_strategy(SummaryStatisticsInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Summary Statistics (Numerical Features):
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    406.864964      2.253027    739.885381
# std                     219.355921      0.951162     72.163846
# min                       0.000000      1.000000    580.000000
# ...

# %% [markdown]
# ## Missing Values Analysis

# %%
missing_values_analyzer = SimpleMissingValuesAnalysis()
missing_values_analyzer.analyze(df)
# Out:
# Missing Values Count by Column:
# Gender                           53
# Income (USD)                   4576
# Income Stability               1683
# Type of Employment             7270
# Current Loan Expenses (USD)     172
# Dependents                     2493
# Credit Score                   1703
# Has Active Credit Card         1566
# Property Age                   4850
# Property Location               356
# Loan Sanction Amount (USD)      340
# dtype: int64
#
# Visualizing Missing Values...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Analyzing a Numerical Feature

# %% [markdown]
# ### Loan Sanction Amount (USD)

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Loan Sanction Amount (USD)')

# %% [markdown]
# ### Applicant Age

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Age')

# %% [markdown]
# ### Income (USD)

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Income (USD)')

# %% [markdown]
# ### Loan Amount Request(USD)

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Loan Amount Request (USD)')

# %% [markdown]
# ### Current Loan Expenses (USD)

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Current Loan Expenses (USD)')

# %% [markdown]
# ### Credit Score

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Credit Score')

# %% [markdown]
# ### Property Age

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Property Age')

# %% [markdown]
# ### Property Price

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Property Price')

# %% [markdown]
# # Analyzing a Categorical Feature

# %% [markdown]
# ## Gender

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Gender')

# %% [markdown]
# ### Income Stability

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Income Stability')

# %% [markdown]
# ### Profession

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Profession')

# %% [markdown]
# ## Type of Employment

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Type of Employment')

# %% [markdown]
# ### Location

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Location')

# %% [markdown]
# ### Expense Type 1

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Expense Type 1')

# %% [markdown]
# ### Expense Type 2

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Expense Type 2')

# %% [markdown]
# ### Dependents

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Dependents')

# %% [markdown]
# ### No. of Defaults

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'No. of Defaults')

# %% [markdown]
# ### Has Active Credit Card

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Has Active Credit Card')

# %% [markdown]
# ### Property Type

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Property Type')

# %% [markdown]
# ### Property Location

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Property Location')

# %% [markdown]
# ### Co-Applicant

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateAnalysis())
univariate_analyzer.execute_analysis(df, 'Co-Applicant')

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Numerical vs numerical features

# %% [markdown]
# ### Loan amount request vs current loan expenses

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Loan Amount Request (USD)', 'Current Loan Expenses (USD)')

# %% [markdown]
# ### Loan amount request vs property price

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Loan Amount Request (USD)', 'Property Price')

# %% [markdown]
# ### Loan amount request vs loan sanction amount

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Loan Amount Request (USD)', 'Loan Sanction Amount (USD)')

# %% [markdown]
# ### Current loan expenses vs Loan sanctioned amount

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Current Loan Expenses (USD)', 'Loan Sanction Amount (USD)')

# %% [markdown]
# ### Property price vs loan sanction amount

# %%
bivariate_analyzer = BivariateAnalyzer(NumericalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Loan Sanction Amount (USD)', 'Property Price')

# %% [markdown]
# ## Categorical vs Numerical Feature

# %% [markdown]
# ### TYpe of Employment vs Loan Sanction Amount (USD)

# %%
bivariate_analyzer.set_strategy(CategoricalVsNumericalAnalysis())
bivariate_analyzer.execute_analysis(df, 'Type of Employment', 'Loan Sanction Amount (USD)')

# %% [markdown]
# ### Income Stability vs Loan Sanction Amount (USD)

# %%
bivariate_analyzer.execute_analysis(df, 'Income Stability', 'Loan Sanction Amount (USD)')

# %% [markdown]
# ### Location vs Loan Sanction Amount (USD)

# %%
bivariate_analyzer.execute_analysis(df, 'Location', 'Loan Sanction Amount (USD)')

# %% [markdown]
# # Multivariate Analysis

# %%
multivariate_analyzer = SimpleMultivariateAnalysis()

selected_features = df[['Loan Sanction Amount (USD)', 'Age', 'Income (USD)', 'Loan Amount Request (USD)',
 'Current Loan Expenses (USD)', 'Credit Score', 'Property Age', 'Property Price']]

multivariate_analyzer.analyze(selected_features)

# %% [markdown]
# ### **Insights from Multivariate Analysis**
#
# ------------------------------------------------
